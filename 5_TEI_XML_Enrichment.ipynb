# %% [markdown]
# <a href="https://colab.research.google.com/github/AnastasiiaLavre/AI4Gov2023/blob/main/5_TEI_XML_Enrichment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook we enrich TEI XMLs generated by Grobid by injecting additional metadata

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tika
# Out:
# Collecting tika
#   Downloading tika-2.6.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tika) (67.7.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tika) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (2023.7.22)
# Building wheels for collected packages: tika
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32621 sha256=db3934bd3cf5124cb80736d919d047754da9666c43486c31a526d471bdc51f86
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built tika
# Installing collected packages: tika
# Successfully installed tika-2.6.0

# %%
# Install Java
# !apt-get install -y openjdk-8-jre-headless

# Set JAVA_HOME environment variable
import os
os.environ['JAVA_HOME'] = '/usr/lib/jvm/java-8-openjdk-amd64'

# Install Apache Tika Python library
# !pip install tika

# Import necessary modules
from tika import parser
from tika import detector

# Test Apache Tika
try:
    parsed = parser.from_buffer("Test Apache Tika.")
    detected_type = detector.from_buffer("Test Apache Tika.")
    print("Detected MIME type:", detected_type)
    print("Extracted text:", parsed['content'])
except Exception as e:
    print("An error occurred while testing Apache Tika:", str(e))
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libxtst6
# Suggested packages:
#   libnss-mdns fonts-dejavu-extra fonts-nanum fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   libxtst6 openjdk-8-jre-headless
# 0 upgraded, 2 newly installed, 0 to remove and 16 not upgraded.
# Need to get 30.8 MB of archives.
# After this operation, 104 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-8-jre-headless amd64 8u382-ga-1~22.04.1 [30.8 MB]
# Fetched 30.8 MB in 1s (47.5 MB/s)
# Selecting previously unselected package libxtst6:amd64.
# (Reading database ... 120901 files and directories currently installed.)
# Preparing to unpack .../libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# Preparing to unpack .../openjdk-8-jre-headless_8u382-ga-1~22.04.1_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u382-ga-1~22.04.1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up openjdk-8-jre-headless:amd64 (8u382-ga-1~22.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Requirement already satisfied: tika in /usr/local/lib/python3.10/dist-packages (2.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tika) (67.7.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tika) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tika) (2023.7.22)
# 2023-09-14 11:23:25,764 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar to /tmp/tika-server.jar.
# INFO:tika.tika:Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar to /tmp/tika-server.jar.
# 2023-09-14 11:23:26,332 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar.md5 to /tmp/tika-server.jar.md5.
# INFO:tika.tika:Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar.md5 to /tmp/tika-server.jar.md5.
# 2023-09-14 11:23:26,617 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# WARNING:tika.tika:Failed to see startup log message; retrying...
# Detected MIME type: text/plain
# Extracted text:
#
#
#
#
#
#
#
#
# Test Apache Tika.

# %% [markdown]
# Adding <data> and <objectName>elements to all TEI XMLs if they do not exist there.

# %%
#add <date> and <objectName> elements to all tei.xml
import os
import xml.etree.ElementTree as ET

# Set the path to the directory containing TEI XML files
tei_xml_dir = '/content/drive/MyDrive/Stanford/TEI XML'

# Set the path to the directory where updated TEI XML files will be saved
output_dir = '/content/drive/MyDrive/Stanford/TEI XML/Enriched'


# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Iterate through TEI XML files in the directory
for filename in os.listdir(tei_xml_dir):
    if filename.endswith('.tei.xml'):
        # Create the full path to the TEI XML file
        tei_xml_file = os.path.join(tei_xml_dir, filename)

        # Read the content of the TEI XML file
        tree = ET.parse(tei_xml_file)
        root = tree.getroot()

        # Find the <publicationStmt> element within the TEI XML
        namespace = {'tei': 'http://www.tei-c.org/ns/1.0'}  # Use the TEI XML namespace if available
        publication_stmt_element = root.find('.//tei:publicationStmt', namespaces=namespace)

        if publication_stmt_element is None:
            print(f"Error: <publicationStmt> element not found in {tei_xml_file}.")
        else:
            # Create the <date> element within the <publicationStmt> element
            date_element = ET.Element('date')
            publication_stmt_element.append(date_element)

            # Create the <objectName> element within the <publicationStmt> element
            object_name_element = ET.Element('objectName')
            publication_stmt_element.append(object_name_element)

            # Save the updated TEI XML to a new file in the output directory
            new_teixml_file = os.path.join(output_dir, filename)
            tree.write(new_teixml_file, encoding='utf-8', xml_declaration=True)

            print(f"Data updated and saved to {new_teixml_file}.")
# Out:
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.008_1_updated.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.008_1_enriched.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_27.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_6.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_24.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_32.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_26.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_3.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_33.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_5.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_7.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_25.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_30.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_19.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_18.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_21.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_5.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_35.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_4.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_4.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_31.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_34.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_7.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_6.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_22.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_3.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_36.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_44.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_37.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_23.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_45.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_47.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_46.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_3.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.001_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_42.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_41.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_5.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_4.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_7.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.001_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_6.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_40.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.009_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_8.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.010_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.010_3.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.010_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.009_3.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_12.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_13.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_39.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.009_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_11.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_38.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_8.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_9.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_10.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_17.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_28.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_14.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_29.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_8.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.008_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_15.tei.xml.

# %% [markdown]
# Injecting required values for dates and symbols from CSV to all TEI XMLs

# %%
#insert values from csv
import os
import csv
import xml.etree.ElementTree as ET

# Set the path to the directory containing TEI XML files
tei_xml_dir = '/content/drive/MyDrive/Stanford/TEI XML/Enriched'

# Set the path to the CSV file
csv_file = '/content/drive/MyDrive/Stanford/TEXT 1 page/formatted_documents/document_data.csv'

# Read the content of each TEI XML file in the directory
for filename in os.listdir(tei_xml_dir):
    if filename.endswith('.tei.xml'):
        # Create the full path to the TEI XML file
        tei_xml_file = os.path.join(tei_xml_dir, filename)

        # Read the content of the specific TEI XML file
        with open(tei_xml_file, 'r', encoding='utf-8') as tei_file:
            tei_xml_content = tei_file.read()

        # Parse the TEI XML content
        root = ET.fromstring(tei_xml_content)

        # Read the CSV file and store the data in a dictionary
        csv_data = {}
        with open(csv_file, 'r', newline='', encoding='utf-8') as csvfile:
            reader = csv.reader(csvfile)
            header = next(reader)  # Read the header row
            for row in reader:
                filename_csv = row[0]
                dates_text = row[1]
                symbols_text = row[2]
                csv_data[filename_csv] = {'dates': dates_text, 'symbols': symbols_text}

        # Get the filename of the current TEI XML file without the extension
        filename_without_extension = os.path.splitext(filename)[0].replace(".tei", "")

        # Check if the filename exists in the CSV data
        if filename_without_extension in csv_data:
            dates_text = csv_data[filename_without_extension]['dates']
            symbols_text = csv_data[filename_without_extension]['symbols']

            # Find or create the <date> element within the TEI XML
            date_element = root.find('.//date')
            if date_element is None:
                date_element = ET.Element('date')
                root.insert(1, date_element)  # Insert as the second child of the root
            date_element.text = dates_text

            # Find or create the <objectName> element within the TEI XML
            object_name_element = root.find('.//objectName')
            if object_name_element is None:
                object_name_element = ET.Element('objectName')
                root.insert(2, object_name_element)  # Insert as the third child of the root
            object_name_element.text = symbols_text

            # Save the updated TEI XML to a new file
            new_teixml_file = os.path.join(tei_xml_dir, filename.replace("_updated.tei", "_enriched.tei"))
            tree = ET.ElementTree(root)
            tree.write(new_teixml_file, encoding='utf-8')

            print(f"Data updated and saved to {new_teixml_file}.")
        else:
            print(f"Error: Filename '{filename_without_extension}' not found in the CSV data.")
# Out:
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_27.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_24.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_3.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_5.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_32.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_33.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_6.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_26.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_7.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_25.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_30.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_35.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_18.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_5.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_4.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_19.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_21.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_31.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_4.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_34.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_6.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_7.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_22.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_37.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_3.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_36.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_44.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_23.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_45.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_47.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_46.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_42.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_41.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.001_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_3.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_4.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_5.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_7.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_6.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.001_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_40.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.009_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.005_8.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.010_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.010_1.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.010_3.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.009_3.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_12.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_13.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.009_2.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_39.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_11.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_38.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.006_8.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_9.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_10.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_17.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_28.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_14.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_29.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_8.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.002 0017 - 0334_15.tei.xml.
# Data updated and saved to /content/drive/MyDrive/Stanford/TEI XML/Enriched/40001521.008_1.tei.xml.
# Error: Filename '40001521.008_1_updated' not found in the CSV data.
# Error: Filename '40001521.008_1_enriched' not found in the CSV data.

# %% [markdown]
# This is the test to see what titles, dates and symbols are now in TEI XMLs

# %%
import os
import xml.etree.ElementTree as ET

# Define the directory containing TEI XML files
tei_dir = '/content/drive/MyDrive/Stanford/TEI XML/Enriched'

# Iterate through TEI XML files in the directory
for filename in os.listdir(tei_dir):
    if filename.endswith('.xml'):
        tei_xml_path = os.path.join(tei_dir, filename)

        # Parse the TEI XML file
        tree = ET.parse(tei_xml_path)
        root = tree.getroot()

        # Extract information from the TEI XML within the publicationStmt element
        title_element = root.find('.//ns0:titleStmt/ns0:title', namespaces={'ns0': 'http://www.tei-c.org/ns/1.0'})
        date_element = root.find('.//ns0:publicationStmt/date', namespaces={'ns0': 'http://www.tei-c.org/ns/1.0'})
        object_name_element = root.find('.//ns0:publicationStmt/objectName', namespaces={'ns0': 'http://www.tei-c.org/ns/1.0'})

        # Get the text content of the elements (if they exist)
        title = title_element.text if title_element is not None else 'N/A'
        date = date_element.text if date_element is not None else 'N/A'
        object_name = object_name_element.text if object_name_element is not None else 'N/A'

        # Print the results
        print(f"Filename: {filename}")
        print(f"Title: {title}")
        print(f"Date: {date}")
        print(f"ObjectName: {object_name}")
        print("=" * 40)  # Separate entries for better readability
# Out:
# Filename: 40001521.002 0017 - 0334_27.tei.xml
# Title: NOTE FOR PARTICIPANTS IN THE CONSULTATIVE GROUP OF EIGHTEEN
# Date: 4 March 1980
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_24.tei.xml
# Title: None
# Date: 31 October 1980, 31 October 1980
# ObjectName: CG.18/W/47, CG.18/INF/13, W/47, INF/13, GATT/1271
# ========================================
# Filename: 40001521.006_2.tei.xml
# Title: None
# Date: None
# ObjectName: CG.18/1, CG.18/1, F/28
# ========================================
# Filename: 40001521.006_3.tei.xml
# Title: ET LE COMMERCE Special Distribution
# Date: 28 February 1985, 1 March 1985, 1 mars 1985
# ObjectName: NF/27
# ========================================
# Filename: 40001521.002 0017 - 0334_5.tei.xml
# Title: None
# Date: 21 August 1984, 6 July 1984, 6 July 1984
# ObjectName: CG.18/W/82, CG.18/INF/25, W/82, INF/25
# ========================================
# Filename: 40001521.002 0017 - 0334_32.tei.xml
# Title: NOTE ON THE TENTH MEETING OF THE CONSULTATIVE GROUP OF EIGHTEEN
# Date: 23 October 1979, 23 October 1979, 23 October 1979
# ObjectName: CG.18/W/32, CG.16/INF/10, W/32, INF/10
# ========================================
# Filename: 40001521.006_1.tei.xml
# Title: None
# Date: 9 July 1985, 9 juillet 1985
# ObjectName: CG.18/INF/29, INF/29
# ========================================
# Filename: 40001521.002 0017 - 0334_33.tei.xml
# Title: NOTE FOR PARTICIPANTS @ IN THE CONSULTATIVE GROUP OF EIGHTEEN
# Date: 13 October 1978
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_6.tei.xml
# Title: NOTE ON THE TWENTY~THIRD MEETING OF THE CONSULTATIVE GROUP OF EIGHTEEN
# Date: 6 April 1984
# ObjectName: CG.18/W/78, CG.18/INF/24, CG.18/W/79, W/78, INF/24, W/79
# ========================================
# Filename: 40001521.002 0017 - 0334_26.tei.xml
# Title: None
# Date: 15 July 1980, 15 JULY 1980, 15 July 1980
# ObjectName: CG.18/W/40, CG.18/INF/12, W/40, INF/12
# ========================================
# Filename: 40001521.002 0017 - 0334_7.tei.xml
# Title: None
# Date: 11 November 1983, 20 October 1983, 20 October 1983
# ObjectName: CG.18/W/75, CG.18/INF/23, CG.18/W/76, W/75, INF/23, W/76, GATT/1340
# ========================================
# Filename: 40001521.002 0017 - 0334_25.tei.xml
# Title: None
# Date: 15 July 1980
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_30.tei.xml
# Title: NOTE ON THE NINTH MEETING OF THE CONSULTATIVE GROUP OF EIGHTHEN
# Date: 10 May 1979, 24 April 1979, 24 April 1979, 24 April 1979
# ObjectName: CG.18/W/29, CG.18/INF/9, CG.18/W/28, W/29, INF/9, W/28
# ========================================
# Filename: 40001521.002 0017 - 0334_35.tei.xml
# Title: None
# Date: 9 June 1978
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_18.tei.xml
# Title: NOTE FOR PARTICIPANTS IN THE CONSULTATIVE GROUP OF EIGHTEEN The attached confidential note, which has been prepared by the secretariat on its own responsibility, outlines the main points made in the course of the seventeenth meeting of the Consultative Group on
# Date: 12 February 1982
# ObjectName: None
# ========================================
# Filename: 40001521.006_5.tei.xml
# Title: ACCORD GENERAL SUR _ zestrzcteo ON TARIFFS AND LES TARIFS DOUANIERS £°;12/1#/29 TRADE ET LE COMMERCE Special Distribution
# Date: 6 July 1984, 6 juillet 1984
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_4.tei.xml
# Title: None
# Date: 26 November 1984, 26 October 1984, 26 October 1984
# ObjectName: cG.18/25, CG.18/W/84, CG.18/INF/26, cG.18/25, W/84, INF/26
# ========================================
# Filename: 40001521.002 0017 - 0334_19.tei.xml
# Title: None
# Date: 12 March 1982, 12 February 1982, 12 February 1982
# ObjectName: CG.18/17, CG.18/W/65, CG.18/INF/18, CG.18/W/66, CG.18/17, W/65, INF/18, W/66
# ========================================
# Filename: 40001521.002 0017 - 0334_21.tei.xml
# Title: None
# Date: 16 October 1981, 16 October 1981
# ObjectName: CG.18/W/56, CG.18/INF/16, CG.18/W/59, W/56, INF/16, W/59
# ========================================
# Filename: 40001521.002 0017 - 0334_31.tei.xml
# Title: NOTE FOR PARTICIPANTS IN THE CONSULTATIVE GROUP OF EIGHTEEN The attached confidential note, which has been prepared by the secretariat on its own responsibility and which is being distributed only to titular and alternate members of the Group, outlines the main points made in the course of the tenth meeting of the Consultative Group on
# Date: 23 October 1979
# ObjectName: None
# ========================================
# Filename: 40001521.006_4.tei.xml
# Title: None
# Date: 25 October 1984, 26 October 1984, 26 octobre 1984
# ObjectName: INF/26
# ========================================
# Filename: 40001521.002 0017 - 0334_34.tei.xml
# Title: None
# Date: 17 November 1978, 13 October 1978, 13 October 1978, 13 October 1978
# ObjectName: CG.18/8, CG.18/W/25, CG.18/INF/8, CG.18/8, W/25, INF/8
# ========================================
# Filename: 40001521.002 0017 - 0334_1.tei.xml
# Title: None
# Date: 9 July 1985, 9 July 1985
# ObjectName: CG.18/INF/29, INF/29, L/5827, L/5831, L/5833, L/5834, L/5836, L/5835, L/5837, L/5842, L/5838
# ========================================
# Filename: 40001521.006_6.tei.xml
# Title: None
# Date: 6 May 1983, 6 mai 1983
# ObjectName: None
# ========================================
# Filename: 40001521.006_7.tei.xml
# Title: None
# Date: 12 February 1982
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_22.tei.xml
# Title: None
# Date: 30 July 1981, 26 June 1981, 26 June 1981
# ObjectName: CG.18/W/52, CG.18/INF/15, W/52, INF/15
# ========================================
# Filename: 40001521.002 0017 - 0334_37.tei.xml
# Title: None
# Date: 21 February 1978
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_3.tei.xml
# Title: Consultative Group of Eighteen
# Date: 28 March 1985, 28 February 1985, 28 February 1985
# ObjectName: CG.18/INF/27, INF/27
# ========================================
# Filename: 40001521.002 0017 - 0334_36.tei.xml
# Title: None
# Date: 20 July 1978, 9 June 1978, 9 JUNE 1978, 9 June 1978
# ObjectName: ca.18/7, CG.18/W/23, ca.18/7, W/22, W/23
# ========================================
# Filename: 40001521.002 0017 - 0334_2.tei.xml
# Title: None
# Date: 14 May 1985, 14 May 1985
# ObjectName: sa.18/27, CG.18/INF/28, sa.18/27, INF/28
# ========================================
# Filename: 40001521.002 0017 - 0334_44.tei.xml
# Title: None
# Date: 23 July 1976, 23 June 1976, 23 JUNE 1976, 23 June 1976
# ObjectName: CG.18/3, CG.18/W/10, CG.18/INF/3, CG.18/W/5, G.18/iW/7, CG.18/W/9, CG.18/3, W/10, INF/3, W/5, iW/7, W/8, W/9
# ========================================
# Filename: 40001521.002 0017 - 0334_23.tei.xml
# Title: None
# Date: 28 April 1981, 27 March 1981, 27 March 1981
# ObjectName: CG.18/W/50, CG.18/INF/14, W/50, INF/14, AIR/1285
# ========================================
# Filename: 40001521.002 0017 - 0334_45.tei.xml
# Title: None
# Date: 19 March 1976, 25 Fabruary 1975, 25 PRERTARY 1976, 25 February 1976
# ObjectName: cG.18/1, G.18/W/2, cG.18/1, W/2, INF/2, GaTT/1174
# ========================================
# Filename: 40001521.002 0017 - 0334_47.tei.xml
# Title: None
# Date: 1 or 1975, 25 November 1975, 25 November 1975
# ObjectName: CG.18/W/1, CG.18/INF/1, W/1, INF/1
# ========================================
# Filename: 40001521.005_2.tei.xml
# Title: None
# Date: 21 June 1982, 9 July 1982, 7 May 1982
# ObjectName: cG.18/W/69, CG.18/W/70, W/69, W/70
# ========================================
# Filename: 40001521.002 0017 - 0334_46.tei.xml
# Title: The attached confidential note, which has been prepared by the secretariat
# Date: 25 November 1975
# ObjectName: None
# ========================================
# Filename: 40001521.005_1.tei.xml
# Title: GENERAL AGREEMENT ON Of Seotenber 1982
# Date: 8 October 1982
# ObjectName: GATT/1319
# ========================================
# Filename: 40001521.002 0017 - 0334_42.tei.xml
# Title: None
# Date: 26 October 1976, 26 OCTOBER 1976, 26 October 1976
# ObjectName: G.18/W/13, CG.18/W/14, W/13, INF/4, W/14
# ========================================
# Filename: 40001521.002 0017 - 0334_41.tei.xml
# Title: NOTE FOR PARTICTPANTS IN THE CONSULTATIVE GROUP OF ELGHTEEN
# Date: 26 October 1976
# ObjectName: None
# ========================================
# Filename: 40001521.001_1.tei.xml
# Title: CONSUL TATIVE GROUP OF EIGHTE EN wat 4-7 MAY 1982 = OE
# Date: 7 MAY 1982, 7 May 1982
# ObjectName: CG.18/W/59, CG.18/W/68, W/59, W/68
# ========================================
# Filename: 40001521.005_3.tei.xml
# Title: None
# Date: 7 May 1982
# ObjectName: CG.18/W/68, GATT/1313, W/68
# ========================================
# Filename: 40001521.005_4.tei.xml
# Title: None
# Date: 12 February 1982, 20 April 1982, 23 December 1981
# ObjectName: PREP.COM/W/1, CG.18/W/66, CG.18/W/41, CG.18/W/60, CG.18/W/59, CG.18/W/59, W/66, W/1, W/41, W/60, W/59, W/59, Spec(81)66
# ========================================
# Filename: 40001521.005_5.tei.xml
# Title: GENERAL AGREEMENT ON CG. 18/W/56
# Date: 15 September 1981, 16 October 1981
# ObjectName: CG.18/W/55, CG.18/W/57, W/56, GATT/1295, W/55, W/57, W/58
# ========================================
# Filename: 40001521.005_7.tei.xml
# Title: GENERAL AGREEMENT ON C6-18/W/50
# Date: 27 March 1981, 2 March 1981
# ObjectName: CG.18/W/46, W/50, GATT/1285, W/46
# ========================================
# Filename: 40001521.005_6.tei.xml
# Title: None
# Date: 26 June 1981
# ObjectName: CG.18/W/53, CG.18/W/55, CG.18/W/54, W/52, W/53, W/55, W/54
# ========================================
# Filename: 40001521.001_2.tei.xml
# Title: Note by the Secretariat
# Date: 21 May 1982, 7 MAY 1982
# ObjectName: PREP.COM/W/5, PREP.COM/W/7, PREP.COM/W/7, W/5, W/7, W/7, spee(82)50
# ========================================
# Filename: 40001521.002 0017 - 0334_40.tei.xml
# Title: NOTE ON THE FIFTH MEETING OF THE CONSULTATIVE GROUP OF EIGHTEEN
# Date: 26 Ooneber 1977, 23 September 1977, 23 SEPTEMBER 1977, 23 September 1977
# ObjectName: CG.18/W/18, CG.18/INF/5, CG.18/W/19, CG.18/W/19, W/18, INF/5, W/19, W/19
# ========================================
# Filename: 40001521.009_1.tei.xml
# Title: GENERAL AGREEMENT ON 1/5387 ssp TARIFFS AND TRADE . Limited Distribution REPORT OF THE CONSULTATIVE GROUP OF EIGHTEEN TO THE COUNCIL OF REPRESENTATIVES
# Date: 23 October 1981, 8 October 1982
# ObjectName: CG.18/W/66, L/5210, W/66
# ========================================
# Filename: 40001521.005_8.tei.xml
# Title: None
# Date: 31 October 1980
# ObjectName: GATT/1271
# ========================================
# Filename: 40001521.010_2.tei.xml
# Title: Pr es s Re le as e G a p
# Date: 7 May 1982, 9 July 1982
# ObjectName: GATT/1314
# ========================================
# Filename: 40001521.010_1.tei.xml
# Title: None
# Date: 23 March 1982, 30 MARCH 1982
# ObjectName: GATT/1313
# ========================================
# Filename: 40001521.010_3.tei.xml
# Title: SIXTEENTH MEETING OF THE CONSULTATIVE GROUP OF EIGHTEEN
# Date: 16 October 1981, 16 October 1981, 18 September 1981
# ObjectName: GATT/1297, GATT/1295
# ========================================
# Filename: 40001521.009_3.tei.xml
# Title: None
# Date: 31 October 1980, 15 July 1980, 31 October 1980, 23 September 1980
# ObjectName: CG.18/W/42, L/5066, L/4204, L/4869, W/42, GATT/1271
# ========================================
# Filename: 40001521.002 0017 - 0334_12.tei.xml
# Title: None
# Date: 8 October 1982
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_13.tei.xml
# Title: None
# Date: 28 October 1982, 8 October 1982, 8 October 1982
# ObjectName: CG.18/W/72, CG.18/INF/21, W/72, INF/21, GATT/1319
# ========================================
# Filename: 40001521.009_2.tei.xml
# Title: GENERAL AGREEMENT ON Oe october 1981 TARIFFS AND TRADE Limited Distribution REPORT OF THE CONSULTATIVE GROUP OF EIGHTEEN TO THE COUNCIL OF REPRESENTATIVES
# Date: 31 October 1980, 16 October 1981
# ObjectName: L/5066
# ========================================
# Filename: 40001521.002 0017 - 0334_39.tei.xml
# Title: The attached confidential note, which has been prepared by the secretariat
# Date: 23 September 1977
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_11.tei.xml
# Title: -GENERAL AGREEMENT ON oc. 18/21
# Date: 23 June 1983, 6 May 1983, 6 May 1983
# ObjectName: CG.18/W/73, CG.18/INF/22, W/73, INF/22
# ========================================
# Filename: 40001521.002 0017 - 0334_38.tei.xml
# Title: NOTE ON THE SIXTH MEETING OF THE CONSULTATIVE
# Date: 15 March 1978, 21 February 1978, 21 FEBRUARY 1978, 21 February 1978
# ObjectName: cG.18/6, CG.18/W/21, CG.18/INF/6, cG.18/6, W/21, INF/6
# ========================================
# Filename: 40001521.006_8.tei.xml
# Title: GENERAL AGREEMENT ON TARIFFS AND TRADE 6.18/INF/17 ACCORD GENERAL SUR LES TARIFS DOUANIERS ET LE COMMERCE 14 october 1981 ACUERDO GENERAL SOBRE ARANCELES ADUANEROS Y COMERCIO Special Distribution
# Date: 14 october 1981, 16 October 1981, 27 March 1981, 16 octobre 1981, 27 mars 1981
# ObjectName: INF/17
# ========================================
# Filename: 40001521.002 0017 - 0334_9.tei.xml
# Title: GENERAL AGREEMENT ON ce. 18/21
# Date: 23 June 1983, 6 May 1983, 6 May 1983
# ObjectName: CG.18/W/73, CG.18/INF/22, W/73, INF/22
# ========================================
# Filename: 40001521.002 0017 - 0334_10.tei.xml
# Title: NOTE FOR PARTICIPANTS IN THE CONSULTATIVE GROUP OF EIGHTEEN The attached confidential note, which has been prepared by the secretariat on its own responsibility, outlines the main points made in the course of the twenty-first meeting of the Consultative Group on 5-6 May 1983
# Date: 6 May 1983
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_17.tei.xml
# Title: None
# Date: 11 June 1982, 7 May 1982, 7 May 1982
# ObjectName: PREP.COM/W/5, PREP.COM/W/7, PREP.COM/W/7, CG.18/W/67, CG.18/INF/19, W/67, INF/19, W/5, W/7, W/7
# ========================================
# Filename: 40001521.002 0017 - 0334_28.tei.xml
# Title: NOTE ON THE ELEVENTH MEETING OF THE CONSULTATIVE GROUP OF BIGHTEEN
# Date: 4 March 1980, 4 March 1980, 4 March 1980, 22 November 1979
# ObjectName: CG.18/W/36, CG.18/INF/11, W/36, INF/11
# ========================================
# Filename: 40001521.002 0017 - 0334_14.tei.xml
# Title: None
# Date: 9 July 1982
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_29.tei.xml
# Title: NOTE FOR PARTICIPA NTS IN THE CONSULTAT IVE GROUP OF EIGHTEEN
# Date: 24 April 1979
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_8.tei.xml
# Title: None
# Date: 6 May 1983
# ObjectName: None
# ========================================
# Filename: 40001521.002 0017 - 0334_15.tei.xml
# Title: None
# Date: 9 July 1982, 9 July 1982
# ObjectName: CG.18/W/69, CG.18/INF/20, CG.18/W/71, W/69, INF/20, W/71, W/368
# ========================================
# Filename: 40001521.008_1.tei.xml
# Title: None
# Date: 12 February 1982, 9.2.82
# ObjectName: CG.18/W/66, W/66
# ========================================
# Filename: 40001521.008_1_updated.tei.xml
# Title: None
# Date: None
# ObjectName: None
# ========================================
# Filename: 40001521.008_1_enriched.tei.xml
# Title: None
# Date: 12 February 1982, 9.2.82
# ObjectName: CG.18/W/66, W/66
# ========================================

# %% [markdown]
# Option 2. Enriching TEI XMLs with beautifulsoup

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %% [markdown]
# Merging two csv files with titles and with dates and symbols

# %%
import csv
import os

# Define the paths to the input CSV files and the output CSV file
input_file1 = '/content/drive/MyDrive/Stanford/PDF 1 page/pdf_titles.csv'
input_file2 = '/content/drive/MyDrive/Stanford/TEXT 1 page/formatted_documents/document_data.csv'
output_file = '/content/drive/MyDrive/Stanford/merged_output_final_test.csv'

# Function to extract filenames without extensions
def extract_filename_without_extension(file_path):
    return os.path.splitext(os.path.basename(file_path))[0]

# Read data from the first input CSV file
data1 = {}
with open(input_file1, 'r', newline='') as csv_file:
    reader = csv.DictReader(csv_file)
    for row in reader:
        filename = extract_filename_without_extension(row['Filename'])
        data1[filename] = row

# Read data from the second input CSV file
data2 = {}
with open(input_file2, 'r', newline='') as csv_file:
    reader = csv.DictReader(csv_file)
    for row in reader:
        filename = row['Document Name']
        data2[filename] = row

# Merge the data from both files based on the common column ('filename')
merged_data = []
for filename, row1 in data1.items():
    if filename in data2:
        row2 = data2[filename]
        row1.update(row2)  # Merge the rows from both files
    merged_data.append(row1)

# Get a list of all column names
column_names = set()
for row in merged_data:
    column_names.update(row.keys())

# Write the merged data to the output CSV file
with open(output_file, 'w', newline='') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=column_names)
    writer.writeheader()  # Write the header row with all columns
    writer.writerows(merged_data)

print(f'Merged data saved to {output_file}')
# Out:
# Merged data saved to /content/drive/MyDrive/Stanford/merged_output_final_test.csv

# %% [markdown]
# Adding elements to TEI XML

# %%
from bs4 import BeautifulSoup

# Set the paths for the TEI XML directory, CSV file, and output directory
tei_xml_directory = '/content/drive/MyDrive/Stanford/TEI XML v2'
#csv_file = '/content/drive/MyDrive/Stanford/merged_output.csv'
#output_directory = '/content/drive/MyDrive/Stanford/TEI XML v2/Enriched'


# Function to update TEI XML files
def update_tei_xml(tei_xml_path):
    # Read the TEI XML file
    with open(tei_xml_path, 'r', encoding='utf-8') as tei_file:
        tei_content = tei_file.read()

    # Parse the TEI XML content using BeautifulSoup
    soup = BeautifulSoup(tei_content, 'xml')

    # Check if <publicationStmt> exists, and if not, create it
    publication_stmt = soup.find('publicationStmt')
    if publication_stmt is None:
        file_desc = soup.find('fileDesc')
        publication_stmt = soup.new_tag('publicationStmt')
        if file_desc is not None:
            file_desc.append(publication_stmt)

    # Check if <date> element exists, and if not, create it
    date_element = publication_stmt.find('date')
    if date_element is None:
        date_element = soup.new_tag('date')
        date_element.string = 'Your Date Value Here'
        publication_stmt.append(date_element)

    # Check if <objectName> element exists, and if not, create it
    object_name_element = publication_stmt.find('objectName')
    if object_name_element is None:
        object_name_element = soup.new_tag('objectName')
        object_name_element.string = 'Your ObjectName Value Here'
        publication_stmt.append(object_name_element)

    # Save the updated TEI XML to the same file
    with open(tei_xml_path, 'w', encoding='utf-8') as updated_tei_file:
        updated_tei_file.write(str(soup))

# Iterate through TEI XML files in the directory
for filename in os.listdir(tei_xml_directory):
    if filename.endswith('tei.xml'):
        tei_xml_path = os.path.join(tei_xml_directory, filename)
        update_tei_xml(tei_xml_path)
        print(f"Updated TEI XML file: {filename}")

print("Processing complete.")
# Out:
# Updated TEI XML file: 40001521.002 0017 - 0334_33.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_6.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_26.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_27.tei.xml
# Updated TEI XML file: 40001521.006_3.tei.xml
# Updated TEI XML file: 40001521.006_2.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_32.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_5.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_7.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_18.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_30.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_25.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_19.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_24.tei.xml
# Updated TEI XML file: 40001521.006_1.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_35.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_31.tei.xml
# Updated TEI XML file: 40001521.006_5.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_4.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_21.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_1.tei.xml
# Updated TEI XML file: 40001521.006_4.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_34.tei.xml
# Updated TEI XML file: 40001521.006_7.tei.xml
# Updated TEI XML file: 40001521.006_6.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_36.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_3.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_22.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_23.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_2.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_37.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_44.tei.xml
# Updated TEI XML file: 40001521.005_3.tei.xml
# Updated TEI XML file: 40001521.005_1.tei.xml
# Updated TEI XML file: 40001521.005_2.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_45.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_47.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_46.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_42.tei.xml
# Updated TEI XML file: 40001521.005_4.tei.xml
# Updated TEI XML file: 40001521.001_1.tei.xml
# Updated TEI XML file: 40001521.005_5.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_41.tei.xml
# Updated TEI XML file: 40001521.005_6.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_40.tei.xml
# Updated TEI XML file: 40001521.001_2.tei.xml
# Updated TEI XML file: 40001521.010_2.tei.xml
# Updated TEI XML file: 40001521.005_7.tei.xml
# Updated TEI XML file: 40001521.010_1.tei.xml
# Updated TEI XML file: 40001521.005_8.tei.xml
# Updated TEI XML file: 40001521.009_1.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_13.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_12.tei.xml
# Updated TEI XML file: 40001521.010_3.tei.xml
# Updated TEI XML file: 40001521.009_3.tei.xml
# Updated TEI XML file: 40001521.009_2.tei.xml
# Updated TEI XML file: 40001521.006_9.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_10.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_39.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_38.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_9.tei.xml
# Updated TEI XML file: 40001521.006_8.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_11.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_15.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_17.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_29.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_28.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_8.tei.xml
# Updated TEI XML file: 40001521.002 0017 - 0334_14.tei.xml
# Updated TEI XML file: 40001521.008_1.tei.xml
# Processing complete.

# %% [markdown]
# Enriching TEI XML with the metadata values

# %%
# Set the paths for the TEI XML directory, CSV file, and output directory

tei_xml_directory = '/content/drive/MyDrive/Stanford/TEI XML v2'
csv_file = '/content/drive/MyDrive/Stanford/merged_output.csv'
output_directory = '/content/drive/MyDrive/Stanford/TEI XML v2/Enriched'

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Read the CSV file and store the data in a dictionary
csv_data = {}
with open(csv_file, 'r', newline='', encoding='utf-8') as csvfile:
    reader = csv.reader(csvfile)
    header = next(reader)  # Read the header row
    for row in reader:
        filename = row[3]
        dates = row[4]
        symbols = row[1]
        csv_data[filename] = {'dates': dates, 'symbols': symbols}

# Process each TEI XML file in the directory
for filename in os.listdir(tei_xml_directory):
    if filename.endswith('.tei.xml'):
        tei_xml_path = os.path.join(tei_xml_directory, filename)
        base_name = os.path.splitext(filename)[0].replace('.tei',"")  # Remove extension from TEI XML filename

        # Check if the base filename exists in the CSV data
        if base_name in csv_data:
            dates = csv_data[base_name]['dates']
            symbols = csv_data[base_name]['symbols']

            # Read the TEI XML file
            with open(tei_xml_path, 'r', encoding='utf-8') as tei_file:
                tei_content = tei_file.read()

            # Parse the TEI XML content using BeautifulSoup with 'lxml' parser
            soup = BeautifulSoup(tei_content, 'xml')

            # Find or create the <date> element and set its text
            date_element = soup.find('date')
            if date_element is None:
                date_element = soup.new_tag('date')
                publication_stmt = soup.find('publicationStmt')
                if publication_stmt:
                    publication_stmt.insert(0, date_element)
            date_element.string = dates

            # Find or create the <objectName> element and set its text
            object_name_element = soup.find('objectName')
            if object_name_element is None:
                object_name_element = soup.new_tag('objectName')
                publication_stmt = soup.find('publicationStmt')
                if publication_stmt:
                    publication_stmt.insert(1, object_name_element)
            object_name_element.string = symbols

            # Save the updated TEI XML to the output directory
            output_xml_path = os.path.join(output_directory, filename)
            with open(output_xml_path, 'w', encoding='utf-8') as updated_tei_file:
                updated_tei_file.write(str(soup))

            print(f"Updated TEI XML file: {filename}")

            # Print filename, dates, and symbols
            print(f"Filename: {filename}")
            print(f"Dates: {dates}")
            print(f"Symbols: {symbols}")

print("Processing complete.")
# Out:
# Updated TEI XML file: 40001521.002 0017 - 0334_33.tei.xml
# Filename: 40001521.002 0017 - 0334_33.tei.xml
# Dates: 13 October 1978
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_6.tei.xml
# Filename: 40001521.002 0017 - 0334_6.tei.xml
# Dates: 6 April 1984
# Symbols: CG.18/W/78, CG.18/INF/24, CG.18/W/79, W/78, INF/24, W/79
# Updated TEI XML file: 40001521.002 0017 - 0334_26.tei.xml
# Filename: 40001521.002 0017 - 0334_26.tei.xml
# Dates: 15 July 1980, 15 JULY 1980, 15 July 1980
# Symbols: CG.18/W/40, CG.18/INF/12, W/40, INF/12
# Updated TEI XML file: 40001521.002 0017 - 0334_27.tei.xml
# Filename: 40001521.002 0017 - 0334_27.tei.xml
# Dates: 4 March 1980
# Symbols:
# Updated TEI XML file: 40001521.006_3.tei.xml
# Filename: 40001521.006_3.tei.xml
# Dates: 28 February 1985, 1 March 1985, 1 mars 1985
# Symbols: NF/27
# Updated TEI XML file: 40001521.006_2.tei.xml
# Filename: 40001521.006_2.tei.xml
# Dates:
# Symbols: CG.18/1, CG.18/1, F/28
# Updated TEI XML file: 40001521.002 0017 - 0334_32.tei.xml
# Filename: 40001521.002 0017 - 0334_32.tei.xml
# Dates: 23 October 1979, 23 October 1979, 23 October 1979
# Symbols: CG.18/W/32, CG.16/INF/10, W/32, INF/10
# Updated TEI XML file: 40001521.002 0017 - 0334_5.tei.xml
# Filename: 40001521.002 0017 - 0334_5.tei.xml
# Dates: 21 August 1984, 6 July 1984, 6 July 1984
# Symbols: CG.18/W/82, CG.18/INF/25, W/82, INF/25
# Updated TEI XML file: 40001521.002 0017 - 0334_7.tei.xml
# Filename: 40001521.002 0017 - 0334_7.tei.xml
# Dates: 11 November 1983, 20 October 1983, 20 October 1983
# Symbols: CG.18/W/75, CG.18/INF/23, CG.18/W/76, W/75, INF/23, W/76, GATT/1340
# Updated TEI XML file: 40001521.002 0017 - 0334_18.tei.xml
# Filename: 40001521.002 0017 - 0334_18.tei.xml
# Dates: 12 February 1982
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_30.tei.xml
# Filename: 40001521.002 0017 - 0334_30.tei.xml
# Dates: 10 May 1979, 24 April 1979, 24 April 1979, 24 April 1979
# Symbols: CG.18/W/29, CG.18/INF/9, CG.18/W/28, W/29, INF/9, W/28
# Updated TEI XML file: 40001521.002 0017 - 0334_25.tei.xml
# Filename: 40001521.002 0017 - 0334_25.tei.xml
# Dates: 15 July 1980
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_19.tei.xml
# Filename: 40001521.002 0017 - 0334_19.tei.xml
# Dates: 12 March 1982, 12 February 1982, 12 February 1982
# Symbols: CG.18/17, CG.18/W/65, CG.18/INF/18, CG.18/W/66, CG.18/17, W/65, INF/18, W/66
# Updated TEI XML file: 40001521.002 0017 - 0334_24.tei.xml
# Filename: 40001521.002 0017 - 0334_24.tei.xml
# Dates: 31 October 1980, 31 October 1980
# Symbols: CG.18/W/47, CG.18/INF/13, W/47, INF/13, GATT/1271
# Updated TEI XML file: 40001521.006_1.tei.xml
# Filename: 40001521.006_1.tei.xml
# Dates: 9 July 1985, 9 juillet 1985
# Symbols: CG.18/INF/29, INF/29
# Updated TEI XML file: 40001521.002 0017 - 0334_35.tei.xml
# Filename: 40001521.002 0017 - 0334_35.tei.xml
# Dates: 9 June 1978
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_31.tei.xml
# Filename: 40001521.002 0017 - 0334_31.tei.xml
# Dates: 23 October 1979
# Symbols:
# Updated TEI XML file: 40001521.006_5.tei.xml
# Filename: 40001521.006_5.tei.xml
# Dates: 6 July 1984, 6 juillet 1984
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_4.tei.xml
# Filename: 40001521.002 0017 - 0334_4.tei.xml
# Dates: 26 November 1984, 26 October 1984, 26 October 1984
# Symbols: cG.18/25, CG.18/W/84, CG.18/INF/26, cG.18/25, W/84, INF/26
# Updated TEI XML file: 40001521.002 0017 - 0334_21.tei.xml
# Filename: 40001521.002 0017 - 0334_21.tei.xml
# Dates: 16 October 1981, 16 October 1981
# Symbols: CG.18/W/56, CG.18/INF/16, CG.18/W/59, W/56, INF/16, W/59
# Updated TEI XML file: 40001521.002 0017 - 0334_1.tei.xml
# Filename: 40001521.002 0017 - 0334_1.tei.xml
# Dates: 9 July 1985, 9 July 1985
# Symbols: CG.18/INF/29, INF/29, L/5827, L/5831, L/5833, L/5834, L/5836, L/5835, L/5837, L/5842, L/5838
# Updated TEI XML file: 40001521.006_4.tei.xml
# Filename: 40001521.006_4.tei.xml
# Dates: 25 October 1984, 26 October 1984, 26 octobre 1984
# Symbols: INF/26
# Updated TEI XML file: 40001521.002 0017 - 0334_34.tei.xml
# Filename: 40001521.002 0017 - 0334_34.tei.xml
# Dates: 17 November 1978, 13 October 1978, 13 October 1978, 13 October 1978
# Symbols: CG.18/8, CG.18/W/25, CG.18/INF/8, CG.18/8, W/25, INF/8
# Updated TEI XML file: 40001521.006_7.tei.xml
# Filename: 40001521.006_7.tei.xml
# Dates: 12 February 1982
# Symbols:
# Updated TEI XML file: 40001521.006_6.tei.xml
# Filename: 40001521.006_6.tei.xml
# Dates: 6 May 1983, 6 mai 1983
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_36.tei.xml
# Filename: 40001521.002 0017 - 0334_36.tei.xml
# Dates: 20 July 1978, 9 June 1978, 9 JUNE 1978, 9 June 1978
# Symbols: ca.18/7, CG.18/W/23, ca.18/7, W/22, W/23
# Updated TEI XML file: 40001521.002 0017 - 0334_3.tei.xml
# Filename: 40001521.002 0017 - 0334_3.tei.xml
# Dates: 28 March 1985, 28 February 1985, 28 February 1985
# Symbols: CG.18/INF/27, INF/27
# Updated TEI XML file: 40001521.002 0017 - 0334_22.tei.xml
# Filename: 40001521.002 0017 - 0334_22.tei.xml
# Dates: 30 July 1981, 26 June 1981, 26 June 1981
# Symbols: CG.18/W/52, CG.18/INF/15, W/52, INF/15
# Updated TEI XML file: 40001521.002 0017 - 0334_23.tei.xml
# Filename: 40001521.002 0017 - 0334_23.tei.xml
# Dates: 28 April 1981, 27 March 1981, 27 March 1981
# Symbols: CG.18/W/50, CG.18/INF/14, W/50, INF/14, AIR/1285
# Updated TEI XML file: 40001521.002 0017 - 0334_2.tei.xml
# Filename: 40001521.002 0017 - 0334_2.tei.xml
# Dates: 14 May 1985, 14 May 1985
# Symbols: sa.18/27, CG.18/INF/28, sa.18/27, INF/28
# Updated TEI XML file: 40001521.002 0017 - 0334_37.tei.xml
# Filename: 40001521.002 0017 - 0334_37.tei.xml
# Dates: 21 February 1978
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_44.tei.xml
# Filename: 40001521.002 0017 - 0334_44.tei.xml
# Dates: 23 July 1976, 23 June 1976, 23 JUNE 1976, 23 June 1976
# Symbols: CG.18/3, CG.18/W/10, CG.18/INF/3, CG.18/W/5, G.18/iW/7, CG.18/W/9, CG.18/3, W/10, INF/3, W/5, iW/7, W/8, W/9
# Updated TEI XML file: 40001521.005_3.tei.xml
# Filename: 40001521.005_3.tei.xml
# Dates: 7 May 1982
# Symbols: CG.18/W/68, GATT/1313, W/68
# Updated TEI XML file: 40001521.005_1.tei.xml
# Filename: 40001521.005_1.tei.xml
# Dates: 8 October 1982
# Symbols: GATT/1319
# Updated TEI XML file: 40001521.005_2.tei.xml
# Filename: 40001521.005_2.tei.xml
# Dates: 21 June 1982, 9 July 1982, 7 May 1982
# Symbols: cG.18/W/69, CG.18/W/70, W/69, W/70
# Updated TEI XML file: 40001521.002 0017 - 0334_45.tei.xml
# Filename: 40001521.002 0017 - 0334_45.tei.xml
# Dates: 19 March 1976, 25 Fabruary 1975, 25 PRERTARY 1976, 25 February 1976
# Symbols: cG.18/1, G.18/W/2, cG.18/1, W/2, INF/2, GaTT/1174
# Updated TEI XML file: 40001521.002 0017 - 0334_47.tei.xml
# Filename: 40001521.002 0017 - 0334_47.tei.xml
# Dates: 1 or 1975, 25 November 1975, 25 November 1975
# Symbols: CG.18/W/1, CG.18/INF/1, W/1, INF/1
# Updated TEI XML file: 40001521.002 0017 - 0334_46.tei.xml
# Filename: 40001521.002 0017 - 0334_46.tei.xml
# Dates: 25 November 1975
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_42.tei.xml
# Filename: 40001521.002 0017 - 0334_42.tei.xml
# Dates: 26 October 1976, 26 OCTOBER 1976, 26 October 1976
# Symbols: G.18/W/13, CG.18/W/14, W/13, INF/4, W/14
# Updated TEI XML file: 40001521.005_4.tei.xml
# Filename: 40001521.005_4.tei.xml
# Dates: 12 February 1982, 20 April 1982, 23 December 1981
# Symbols: PREP.COM/W/1, CG.18/W/66, CG.18/W/41, CG.18/W/60, CG.18/W/59, CG.18/W/59, W/66, W/1, W/41, W/60, W/59, W/59, Spec(81)66
# Updated TEI XML file: 40001521.001_1.tei.xml
# Filename: 40001521.001_1.tei.xml
# Dates: 7 MAY 1982, 7 May 1982
# Symbols: CG.18/W/59, CG.18/W/68, W/59, W/68
# Updated TEI XML file: 40001521.005_5.tei.xml
# Filename: 40001521.005_5.tei.xml
# Dates: 15 September 1981, 16 October 1981
# Symbols: CG.18/W/55, CG.18/W/57, W/56, GATT/1295, W/55, W/57, W/58
# Updated TEI XML file: 40001521.002 0017 - 0334_41.tei.xml
# Filename: 40001521.002 0017 - 0334_41.tei.xml
# Dates: 26 October 1976
# Symbols:
# Updated TEI XML file: 40001521.005_6.tei.xml
# Filename: 40001521.005_6.tei.xml
# Dates: 26 June 1981
# Symbols: CG.18/W/53, CG.18/W/55, CG.18/W/54, W/52, W/53, W/55, W/54
# Updated TEI XML file: 40001521.002 0017 - 0334_40.tei.xml
# Filename: 40001521.002 0017 - 0334_40.tei.xml
# Dates: 26 Ooneber 1977, 23 September 1977, 23 SEPTEMBER 1977, 23 September 1977
# Symbols: CG.18/W/18, CG.18/INF/5, CG.18/W/19, CG.18/W/19, W/18, INF/5, W/19, W/19
# Updated TEI XML file: 40001521.001_2.tei.xml
# Filename: 40001521.001_2.tei.xml
# Dates: 21 May 1982, 7 MAY 1982
# Symbols: PREP.COM/W/5, PREP.COM/W/7, PREP.COM/W/7, W/5, W/7, W/7, spee(82)50
# Updated TEI XML file: 40001521.010_2.tei.xml
# Filename: 40001521.010_2.tei.xml
# Dates: 7 May 1982, 9 July 1982
# Symbols: GATT/1314
# Updated TEI XML file: 40001521.005_7.tei.xml
# Filename: 40001521.005_7.tei.xml
# Dates: 27 March 1981, 2 March 1981
# Symbols: CG.18/W/46, W/50, GATT/1285, W/46
# Updated TEI XML file: 40001521.010_1.tei.xml
# Filename: 40001521.010_1.tei.xml
# Dates: 23 March 1982, 30 MARCH 1982
# Symbols: GATT/1313
# Updated TEI XML file: 40001521.005_8.tei.xml
# Filename: 40001521.005_8.tei.xml
# Dates: 31 October 1980
# Symbols: GATT/1271
# Updated TEI XML file: 40001521.009_1.tei.xml
# Filename: 40001521.009_1.tei.xml
# Dates: 23 October 1981, 8 October 1982
# Symbols: CG.18/W/66, L/5210, W/66
# Updated TEI XML file: 40001521.002 0017 - 0334_13.tei.xml
# Filename: 40001521.002 0017 - 0334_13.tei.xml
# Dates: 28 October 1982, 8 October 1982, 8 October 1982
# Symbols: CG.18/W/72, CG.18/INF/21, W/72, INF/21, GATT/1319
# Updated TEI XML file: 40001521.002 0017 - 0334_12.tei.xml
# Filename: 40001521.002 0017 - 0334_12.tei.xml
# Dates: 8 October 1982
# Symbols:
# Updated TEI XML file: 40001521.010_3.tei.xml
# Filename: 40001521.010_3.tei.xml
# Dates: 16 October 1981, 16 October 1981, 18 September 1981
# Symbols: GATT/1297, GATT/1295
# Updated TEI XML file: 40001521.009_3.tei.xml
# Filename: 40001521.009_3.tei.xml
# Dates: 31 October 1980, 15 July 1980, 31 October 1980, 23 September 1980
# Symbols: CG.18/W/42, L/5066, L/4204, L/4869, W/42, GATT/1271
# Updated TEI XML file: 40001521.009_2.tei.xml
# Filename: 40001521.009_2.tei.xml
# Dates: 31 October 1980, 16 October 1981
# Symbols: L/5066
# Updated TEI XML file: 40001521.006_9.tei.xml
# Filename: 40001521.006_9.tei.xml
# Dates: 14 October 1981, 16 October 1981, 16 octobre 1981
# Symbols: nF/16
# Updated TEI XML file: 40001521.002 0017 - 0334_10.tei.xml
# Filename: 40001521.002 0017 - 0334_10.tei.xml
# Dates: 6 May 1983
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_39.tei.xml
# Filename: 40001521.002 0017 - 0334_39.tei.xml
# Dates: 23 September 1977
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_38.tei.xml
# Filename: 40001521.002 0017 - 0334_38.tei.xml
# Dates: 15 March 1978, 21 February 1978, 21 FEBRUARY 1978, 21 February 1978
# Symbols: cG.18/6, CG.18/W/21, CG.18/INF/6, cG.18/6, W/21, INF/6
# Updated TEI XML file: 40001521.002 0017 - 0334_9.tei.xml
# Filename: 40001521.002 0017 - 0334_9.tei.xml
# Dates: 23 June 1983, 6 May 1983, 6 May 1983
# Symbols: CG.18/W/73, CG.18/INF/22, W/73, INF/22
# Updated TEI XML file: 40001521.006_8.tei.xml
# Filename: 40001521.006_8.tei.xml
# Dates: 14 october 1981, 16 October 1981, 27 March 1981, 16 octobre 1981, 27 mars 1981
# Symbols: INF/17
# Updated TEI XML file: 40001521.002 0017 - 0334_11.tei.xml
# Filename: 40001521.002 0017 - 0334_11.tei.xml
# Dates: 23 June 1983, 6 May 1983, 6 May 1983
# Symbols: CG.18/W/73, CG.18/INF/22, W/73, INF/22
# Updated TEI XML file: 40001521.002 0017 - 0334_15.tei.xml
# Filename: 40001521.002 0017 - 0334_15.tei.xml
# Dates: 9 July 1982, 9 July 1982
# Symbols: CG.18/W/69, CG.18/INF/20, CG.18/W/71, W/69, INF/20, W/71, W/368
# Updated TEI XML file: 40001521.002 0017 - 0334_17.tei.xml
# Filename: 40001521.002 0017 - 0334_17.tei.xml
# Dates: 11 June 1982, 7 May 1982, 7 May 1982
# Symbols: PREP.COM/W/5, PREP.COM/W/7, PREP.COM/W/7, CG.18/W/67, CG.18/INF/19, W/67, INF/19, W/5, W/7, W/7
# Updated TEI XML file: 40001521.002 0017 - 0334_29.tei.xml
# Filename: 40001521.002 0017 - 0334_29.tei.xml
# Dates: 24 April 1979
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_28.tei.xml
# Filename: 40001521.002 0017 - 0334_28.tei.xml
# Dates: 4 March 1980, 4 March 1980, 4 March 1980, 22 November 1979
# Symbols: CG.18/W/36, CG.18/INF/11, W/36, INF/11
# Updated TEI XML file: 40001521.002 0017 - 0334_8.tei.xml
# Filename: 40001521.002 0017 - 0334_8.tei.xml
# Dates: 6 May 1983
# Symbols:
# Updated TEI XML file: 40001521.002 0017 - 0334_14.tei.xml
# Filename: 40001521.002 0017 - 0334_14.tei.xml
# Dates: 9 July 1982
# Symbols:
# Updated TEI XML file: 40001521.008_1.tei.xml
# Filename: 40001521.008_1.tei.xml
# Dates: 12 February 1982, 9.2.82
# Symbols: CG.18/W/66, W/66
# Processing complete.
